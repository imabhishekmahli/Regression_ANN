# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
df = pd.read_csv("/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# 25%      3.00000    8.127500    0.000000           0.63000
# 50%      3.50000    8.560000    1.000000           0.72000
# 75%      4.00000    9.040000    1.000000           0.82000
# max      5.00000    9.920000    1.000000           0.97000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.drop(columns=['Serial No.'],inplace=True)

# %%
X = df.iloc[:,0:7]
y = df.iloc[:,-1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history=model.fit(X_train_scaled,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 20ms/step - loss: 0.2004 - val_loss: 0.1583
# Epoch 2/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1163 - val_loss: 0.0842
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0597 - val_loss: 0.0392
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0267 - val_loss: 0.0171
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - val_loss: 0.0109
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 7/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 9/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 10/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 11/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 12/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 13/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 15/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 16/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 20/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 23/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 24/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 25/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 27/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 28/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 31/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0066
# Epoch 32/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 33/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0064
# Epoch 35/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 36/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 37/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 38/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 40/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0059
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 45/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 47/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 48/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 49/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 51/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 56/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 59/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 61/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 62/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 63/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 64/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 65/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 66/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 69/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 71/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 72/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 77/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 78/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 79/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 80/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 82/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 83/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 84/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 85/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 86/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 88/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 89/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 90/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 91/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 94/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 95/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 100/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0040

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7618545556238862

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model.predict(X_test)
# Out:
# array([[43.14477 ],
#        [43.737316],
#        [48.70718 ],
#        [43.9379  ],
#        [45.682285],
#        [41.995995],
#        [43.503166],
#        [43.660107],
#        [45.32674 ],
#        [43.667263],
#        [43.39555 ],
#        [39.95323 ],
#        [44.1663  ],
#        [46.127033],
#        [44.842957],
#        [46.41364 ],
#        [42.421246],
#        [44.519794],
#        [47.331326],
#        [43.07508 ],
#        [41.335888],
#        [44.35452 ],
#        [45.425747],
#        [41.5003  ],
#        [45.79758 ],
#        [42.6459  ],
#        [46.76698 ],
#        [43.120995],
#        [46.28334 ],
#        [44.52785 ],
#        [42.14917 ],
#        [45.37281 ],
#        [41.224815],
#        [47.527702],
#        [40.717712],
#        [45.86879 ],
#        [42.372803],
#        [42.32384 ],
#        [43.089237],
#        [47.58305 ],
#        [41.00935 ],
#        [43.094177],
#        [43.151875],
#        [48.692326],
#        [46.002754],
#        [39.882854],
#        [42.082184],
#        [43.13164 ],
#        [43.26412 ],
#        [43.46148 ],
#        [46.11717 ],
#        [47.760952],
#        [47.35022 ],
#        [41.86799 ],
#        [42.691532],
#        [42.660778],
#        [44.27844 ],
#        [42.82363 ],
#        [43.881615],
#        [43.956738],
#        [38.852512],
#        [43.53772 ],
#        [42.94487 ],
#        [46.906208],
#        [48.335903],
#        [42.3389  ],
#        [44.449406],
#        [44.78017 ],
#        [47.18398 ],
#        [44.369976],
#        [41.659176],
#        [42.999676],
#        [46.23581 ],
#        [40.785595],
#        [47.88258 ],
#        [43.148563],
#        [45.71064 ],
#        [46.184254],
#        [43.434788],
#        [44.669987],
#        [45.614902],
#        [41.50396 ],
#        [48.3216  ],
#        [44.670887],
#        [45.576008],
#        [43.750763],
#        [46.49568 ],
#        [47.511463],
#        [40.99342 ],
#        [42.312855],
#        [43.159107],
#        [43.281178],
#        [42.69425 ],
#        [44.54559 ],
#        [45.80557 ],
#        [45.923504],
#        [46.626736],
#        [40.77365 ],
#        [44.647747],
#        [43.837543]], dtype=float32)
